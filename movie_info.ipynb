# %%
import requests
import pandas as pd
import numpy as np
import os
import time
import datetime
import json

# %%
movie_2009 = pd.read_csv('캡스톤데이터/KOBIS_연도별박스오피스_2009.csv')
movie_2010 = pd.read_csv('캡스톤데이터/KOBIS_연도별박스오피스_2010.csv')
movie_2011 = pd.read_csv('캡스톤데이터/KOBIS_연도별박스오피스_2011.csv')
movie_2012 = pd.read_csv('캡스톤데이터/KOBIS_연도별박스오피스_2012.csv')
movie_2013 = pd.read_csv('캡스톤데이터/KOBIS_연도별박스오피스_2013.csv')
movie_2014 = pd.read_csv('캡스톤데이터/KOBIS_연도별박스오피스_2014.csv')
movie_2015 = pd.read_csv('캡스톤데이터/KOBIS_연도별박스오피스_2015.csv')
movie_2016 = pd.read_csv('캡스톤데이터/KOBIS_연도별박스오피스_2016.csv')  
movie_2017 = pd.read_csv('캡스톤데이터/KOBIS_연도별박스오피스_2017.csv')
movie_2018 = pd.read_csv('캡스톤데이터/KOBIS_연도별박스오피스_2018.csv')
movie_2019 = pd.read_csv('캡스톤데이터/KOBIS_연도별박스오피스_2019.csv')

# %%
movie_2009.drop(['매출액 점유율','대표국적','국적','순위'],axis=1,inplace=True)
movie_2010.drop(['매출액 점유율','대표국적','국적','순위'],axis=1,inplace=True)
movie_2011.drop(['매출액 점유율','대표국적','국적','순위'],axis=1,inplace=True)
movie_2012.drop(['매출액 점유율','대표국적','국적','순위'],axis=1,inplace=True)
movie_2013.drop(['매출액 점유율','대표국적','국적','순위'],axis=1,inplace=True)
movie_2014.drop(['매출액 점유율','대표국적','국적','순위'],axis=1,inplace=True)
movie_2015.drop(['매출액 점유율','대표국적','국적','순위'],axis=1,inplace=True)
movie_2016.drop(['매출액 점유율','대표국적','국적','순위'],axis=1,inplace=True)
movie_2017.drop(['매출액 점유율','대표국적','국적','순위'],axis=1,inplace=True)
movie_2018.drop(['매출액 점유율','대표국적','국적','순위'],axis=1,inplace=True)
movie_2019.drop(['매출액 점유율','대표국적','국적','순위'],axis=1,inplace=True)

# %%
movie_2009 = movie_2009.drop(movie_2009.index[1182:])

# %%
movie_2009["관객수"] = movie_2009["관객수"].astype(int)
movie_2009_df = movie_2009[movie_2009["관객수"] >= 10000].reset_index(drop=True)
movie_df10 = movie_2009_df.reset_index(drop=True)

# %%
movie_2010 = movie_2010.drop(movie_2010.index[1358:])

# %%
movie_2010["관객수"] = movie_2010["관객수"].astype(int)
movie_2010_df = movie_2010[movie_2010["관객수"] >= 10000].reset_index(drop=True)
movie_df11 = movie_2010_df.reset_index(drop=True)

# %%
movie_2011 = movie_2011.drop(movie_2011.index[2153:])

# %%
movie_2011["관객수"] = movie_2011["관객수"].astype(int)
movie_2011_df = movie_2011[movie_2011["관객수"] >= 10000].reset_index(drop=True)
movie_df7 = movie_2011_df.reset_index(drop=True)

# %%
movie_2012 = movie_2012.drop(movie_2012.index[3291:])

# %%
#movie_2012["관객수"] = movie_2012["관객수"].str.replace(",","")
movie_2012["관객수"] = movie_2012["관객수"].astype(int)
movie_2012_df = movie_2012[movie_2012["관객수"] >= 10000].reset_index(drop=True)
movie_df8 = movie_2012_df.reset_index(drop=True)

# %%
movie_2013 = movie_2013.drop(movie_2013.index[3627:])

# %%
#movie_2013["관객수"] = movie_2013["관객수"].str.replace(",","")
movie_2013["관객수"] = movie_2013["관객수"].astype(int)
movie_2013_df = movie_2013[movie_2013["관객수"] >= 10000].reset_index(drop=True)
movie_df9 = movie_2013_df.reset_index(drop=True)

# %%
movie_2014 = movie_2014.drop(movie_2014.index[3363:])

# %%
movie_2014["관객수"] = movie_2014["관객수"].str.replace(",","")
movie_2014["관객수"] = movie_2014["관객수"].astype(int)
movie_2014_df = movie_2014[movie_2014["관객수"] >= 10000].reset_index(drop=True)
movie_df1 = movie_2014_df.reset_index(drop=True)

# %%
movie_2015 = movie_2015.drop(movie_2015.index[3456:])

# %%
movie_2015["관객수"] = movie_2015["관객수"].str.replace(",","")
movie_2015["관객수"] = movie_2015["관객수"].astype(int)
movie_2015_df = movie_2015[movie_2015["관객수"] >= 10000].reset_index(drop=True)
movie_df2 = movie_2015.reset_index(drop=True)

# %%
movie_2016 = movie_2016.drop(movie_2016.index[4297:])

# %%
#movie_2016["관객수"] = movie_2016["관객수"].str.replace(",","")
movie_2016["관객수"] = movie_2016["관객수"].astype(int)
movie_2016_df = movie_2016[movie_2016["관객수"] >= 10000].reset_index(drop=True)
movie_df3 = movie_2016_df.reset_index(drop=True)

# %%
movie_2017 = movie_2017.drop(movie_2017.index[4806])

# %%
#movie_2017["관객수"] = movie_2017["관객수"].str.replace(",","")
movie_2017["관객수"] = movie_2017["관객수"].astype(int)
movie_2017_df = movie_2017[movie_2017["관객수"] >= 10000].reset_index(drop=True)
movie_df4 = movie_2017_df.reset_index(drop=True)

# %%
movie_2018 = movie_2018.drop(movie_2018.index[5003:])

# %%
#movie_2018["관객수"] = movie_2018["관객수"].str.replace(",","")
movie_2018["관객수"] = movie_2018["관객수"].astype(int)
movie_2018_df = movie_2018[movie_2018["관객수"] >= 10000].reset_index(drop=True)
movie_df5 = movie_2018_df.reset_index(drop=True)

# %%
movie_2019 = movie_2019.drop(movie_2019.index[4889:])

# %%
#movie_2019["관객수"] = movie_2019["관객수"].str.replace(",","")
movie_2019["관객수"] = movie_2019["관객수"].astype(int)
movie_2019_df = movie_2019[movie_2019["관객수"] >= 10000].reset_index(drop=True)
movie_df6 = movie_2019_df.reset_index(drop=True)

# %%
movie_df = pd.concat([movie_df4,movie_df1,movie_df2,movie_df3,movie_df5,movie_df6,movie_df7,movie_df8,movie_df9,movie_df10,movie_df11],ignore_index=True)

# %%
movie_df
# Out:
#                          영화명         개봉일          매출액       관객수  스크린수    상영횟수  \
# 0                      택시운전사  2017-08-02  95853645649  12186327  1906  184075
# 1                  신과함께-죄와 벌  2017-12-20  68350496432   8539495  1912   91301
# 2                         공조  2017-01-18  63783051326   7817618  1392  142989
# 3                스파이더맨: 홈 커밍  2017-07-05  59125813820   7258678  1965  164448
# 4                       범죄도시  2017-10-03  56318014149   6879841  1315  149334
# ...                      ...         ...          ...       ...   ...     ...
# 6438                     소라닌  2010-08-26    81223000      10913  13.0   578.0
# 6439              춤추는 꿈틀이 밴드  2010-02-04    72851000      10885  47.0   718.0
# 6440                내 남자의 순이  2010-05-27    73108500      10449  99.0  2013.0
# 6441  샤인 어 라이트(1st 지드래곤 콘서트)  2010-04-15    91164000      10349  14.0   227.0
# 6442                  셉템버 이슈  2010-01-28    78736700      10202  11.0   752.0
#
#                            배급사
# ...

# %%
movie_df.to_excel("movie.xlsx",index = False)  #일단_movie

# %%
movieNm = movie_df['영화명']
movieNm
# Out:
# 0                        택시운전사
# 1                    신과함께-죄와 벌
# 2                           공조
# 3                  스파이더맨: 홈 커밍
# 4                         범죄도시
#                  ...
# 6438                       소라닌
# 6439                춤추는 꿈틀이 밴드
# 6440                  내 남자의 순이
# 6441    샤인 어 라이트(1st 지드래곤 콘서트)
# 6442                    셉템버 이슈
# Name: 영화명, Length: 6443, dtype: object

# %%
def get_movie_data(movieNm):
    url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json"
    params = {"key":"1b1af4ef8945a650d50594a737f45090", "movieNm":movieNm}
    r = requests.get(url, params=params)
    return r.json()

# %%
def get_movie_data(movieNm):
    url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json"
    params = {"key":"1b1af4ef8945a650d50594a737f45090", "movieNm":movieNm}  
    r = requests.get(url, params=params)
    return r.json()

# %%
def make_movie_df(movieNm):
    movie_df = pd.DataFrame(columns = ["movieCd", "movieNm", "director","prdtYear", "openDt", "typeNm", "repNationNm", "repGenreNm", "companyNm"])
    for i in list(movieNm):
        try:
            for data in get_movie_data(i)['movieListResult']['movieList']:
                if len(data["directors"]) >= 2:
                    director = data["directors"][0]["peopleNm"]
                elif len(data["directors"]) == 1:
                    director = data["directors"][0]["peopleNm"]
                if len(data["companys"]) >= 2:
                    companyNm = data["companys"][0]["companyNm"]
                elif len(data["companys"]) == 1:
                    companyNm = data["companys"][0]["companyNm"] 
                movie_df.loc[len(movie_df)] = [
                    data["movieCd"],
                    data["movieNm"],
                    director,
                    data["prdtYear"],
                    data["openDt"],
                    data["typeNm"],
                    data["repNationNm"],
                    data["repGenreNm"],
                    companyNm
                ]
        except:
            print(i)
    return movie_df

# %%
movie_info_df = make_movie_df(movieNm)
# Out:
# 야곱 신부의 편지
# 한강블루스
# 그저 그런 여배우와 단신 대머리남의 연애
# 2015 GSFF 단편 초청 2
# 도도하라
# 블랙스톤
# 미스피츠
# 비욘드 더 포레스트
# 앨리스는 이제 여기 살지 않는다
# 젊은 퇴를레스
# 클라우드 아틀라스
# 위크엔드 인 파리
# 닥터 불
# 대복성
# 눈 덮인 땅의 꿈 + 내가 사는 나라
# 아이
# 세 가지 시대
# 하이 사인 & 제물 & 극장
# 판타스틱 플래닛
# 자전거, 도시
# 오직 사랑하는 이들만이 살아남는다
# 대부 : 끝나지 않은 이야기
# 소년들
# 집으로 간다
# 클래스
# 스트리트 신
# 네브라스카
# 바다에서 온 편지
# 진실을 밝혀라 2: 국가기구
# 서울독립영화제2015 개막작
# 배니싱 포인트
# 해드윈의 선택
# 리브 앤 다이
# 반칙왕
# 모넬라 2
# 48미터
# 카페 드 플로르
# 호세마리아 신부의 길
# 인디포럼2015 폐막식
# 제16회 대구단편영화제 경쟁9
# 수메 - 혁명의 사운드
# B-무비: 서베를린의 환희와 사운드
# 몬티 파이튼 - 코미디의 전설
# 강가의 집
# 페삭의 처녀 1968 & 페삭의 처녀 1979
# 프릭 아웃
# 보트 & 하얀 얼굴 & 경찰
# 시라노
# 인디애니페스트2015-이성강 감독 특별전
# 노스모킹
# 백야
# 가자 항해자여
# 키드 갈라하드
# 학교 가는 길
# 쇼 피플
# 10개월
# 2015 최강애니전-그 남자는 거기 있었다
# 2015 최강애니전-서울
# 불타는 두리안의 강
# 대나무집
# 늑대 여인
# 이탈리안 갱스터
# 지금, 만나러 갑니다
# 삼거리극장
# 천녀유혼 3-도도도
# 뱅크 잡
# 반 고흐: 위대한 유산
# 인디포럼2015 발효 가족
# 지금, 만나러 가요
# 에어메일
# 제16회 대구단편영화제 경쟁1
# 이라크 전쟁의 전말
# 2015 GSFF 폐막식
# 라 보엠
# 어제영화-구교환&이옥섭 감독 단편
# 테러
# 헌팅 그라운드
# 하나 둘 셋
# 검열된 목소리
# 스위스 비밀계좌를 팝니다
# 결투자들
# 라오스
# ...

# %% [raw]
# movie_info_df = pd.read_excel('movie_info.xlsx', index_col=0)  #_일단_movie_info

# %%
movie_info_df
# Out:
#         movieCd                 movieNm    director  prdtYear      openDt  \
# 0      20162869                   택시운전사          장훈    2017.0  20170802.0
# 1      20001478              택시 운전수의 사랑         진이문    2000.0         NaN
# 2      20098868              택시 운전사의 고백         진이문       NaN         NaN
# 3      20150976               신과함께-죄와 벌         김용화    2017.0  20171220.0
# 4      20215601               공조2:인터내셔날         이석훈    2021.0         NaN
# ...         ...                     ...         ...       ...         ...
# 15740  20100775                     소라닌     미키 타카히로    2010.0  20100826.0
# 15741  20100011              춤추는 꿈틀이 밴드  토마스 보르히 닐슨    2008.0  20100204.0
# 15742  20100277                내 남자의 순이         김호준    2010.0  20100527.0
# 15743  20100201  샤인 어 라이트(1st 지드래곤 콘서트)        정치영     2010.0  20100415.0
# 15744  20090639                  셉템버 이슈    R.J. 커들러    2009.0  20100128.0
#
#       typeNm repNationNm repGenreNm     companyNm
# ...

# %%
movie_info_df.to_excel("일단_movie_info.xlsx",encoding="utf-8") #손보기전

# %%
movie_info_df = movie_info_df.drop_duplicates("movieCd").reset_index(drop=True)

# %%
movie_info_df['openDt'] = movie_info_df['openDt'].dropna()

# %%
movie_info_df = movie_info_df.dropna(subset = ['openDt'])

# %%
movie_info_df = movie_info_df[movie_info_df['openDt'].notna()]

# %% [raw]
# movie_info_df['openDt'] = pd.to_datetime(movie_info_df['openDt'])
# movie_info_date = (movie_info_df['openDt'] >= '2009-01-01') & (movie_info_df['openDt'] <= '2019-12-31')
# movie_info_df = movie_info_df[movie_info_date]

# %%
movie_info_df
# Out:
#        movieCd                 movieNm    director  prdtYear      openDt  \
# 0     20162869                   택시운전사          장훈    2017.0  20170802.0
# 1     20150976               신과함께-죄와 벌         김용화    2017.0  20171220.0
# 2     20151228                      공조         김성훈    2016.0  20170118.0
# 3     20167303             스파이더맨: 홈 커밍        존 왓츠    2017.0  20170705.0
# 4     20172742                    범죄도시         강윤성    2017.0  20171003.0
# ...        ...                     ...         ...       ...         ...
# 6373  20100775                     소라닌     미키 타카히로    2010.0  20100826.0
# 6374  20100011              춤추는 꿈틀이 밴드  토마스 보르히 닐슨    2008.0  20100204.0
# 6375  20100277                내 남자의 순이         김호준    2010.0  20100527.0
# 6376  20100201  샤인 어 라이트(1st 지드래곤 콘서트)        정치영     2010.0  20100415.0
# 6377  20090639                  셉템버 이슈    R.J. 커들러    2009.0  20100128.0
#
#      typeNm repNationNm repGenreNm     companyNm
# ...

# %%
movie_info_df.to_excel("일단_movie_info2.xlsx",encoding="utf-8") #손본후

# %% [markdown]
# ----------------------------------------------------------

# %%
movieCd = movie_info_df["movieCd"]

# %%
def get_movie_detail(movieCd):
    url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json"
    params = {"key":"6b2b3abda68f098094da3e5915d7ee05", "movieCd":movieCd}
    r = requests.get(url, params=params)
    return r.json()

# %%
def make_movie_detail_df(movie_info_df):
    movie_detail_df = pd.DataFrame(columns=["movieCd", 
                                            "movieNm", 
                                            "showTm", 
                                            "watchGradeNm", 
                                            "actor_1",
                                            "actor_2",
                                            "actor_3",
                                            "companyNm"
                                            ])
    for i in list(movieCd):
        try:
            data = get_movie_detail(i)['movieInfoResult']['movieInfo']
            actor_list = []
            if len(data["audits"]) >= 2:
                watchGradeNm = data["audits"][0]["watchGradeNm"]
            elif len(data["audits"]) == 1:
                watchGradeNm = data["audits"][0]["watchGradeNm"]
            if len(data["companys"]) >= 2:
                companyNm = data["companys"][0]["companyNm"]
            elif len(data["companys"]) == 1:
                companyNm = data["companys"][0]["companyNm"] 
            if len(data["actors"]) >= 3:
                actor_list = [
                    data["actors"][0]["peopleNm"],
                    data["actors"][1]["peopleNm"],
                    data["actors"][2]["peopleNm"]
                ]
            else:
                for i in range(len(data["actors"])):
                    actor_list.append(data["actors"][i]["peopleNm"])
                for i in range(3-len(data["actors"])):
                    actor_list.append("")
            movie_detail_df.loc[len(movie_detail_df)] = [
                data["movieCd"],
                data["movieNm"],
                data["showTm"],
                watchGradeNm,
                *actor_list,
                companyNm
            ]
        except:
             print(i)
    return movie_detail_df

# %%
movie_detail_df = make_movie_detail_df(movieCd)

# %%
movie_detail_df
# Out:
#        movieCd                 movieNm showTm watchGradeNm  actor_1   actor_2  \
# 0     20162869                   택시운전사    137     15세이상관람가      이수민       송강호
# 1     20150976               신과함께-죄와 벌    139     12세이상관람가      하정우       차태현
# 2     20151228                      공조    125     15세이상관람가      이재남        현빈
# 3     20167303             스파이더맨: 홈 커밍    133     12세이상관람가  제이콥 배덜런     톰 홀랜드
# 4     20172742                    범죄도시    121      청소년관람불가      마동석       윤계상
# ...        ...                     ...    ...          ...      ...       ...
# 6373  20100775                     소라닌    125     12세이상관람가    코라 켄고  미야자키 아오이
# 6374  20100011              춤추는 꿈틀이 밴드     80        전체관람가      엄상현       이장원
# 6375  20100277                내 남자의 순이     91     15세이상관람가      박해미       이태성
# 6376  20100201  샤인 어 라이트(1st 지드래곤 콘서트)    101     12세이상관람가
# 6377  20090639                  셉템버 이슈     90        전체관람가   안나 윈투어
#
#           actor_3                 companyNm
# ...

# %%
movie_detail_df.to_excel("일단_movie_detail.xlsx",index = F)

# %% [markdown]
# -----------------------------------------------

# %% [markdown]
# result1(boxoffice), result2(movie + boxoffice)

# %%
movie_df = pd.read_csv('movie.csv', index_col=0)

# %%
movie_info = pd.read_csv('일단_movie_info.csv', index_col=0)

# %%
movie_info = movie_info.drop_duplicates("movieCd").reset_index(drop=True)

# %%
movie_info['openDt'] = pd.to_datetime(movie_info['openDt'])

# %%
movie_info.drop(['companyNm'],axis=1,inplace=True)

# %%
movie_detail = pd.read_csv('최종_movie_detail.csv', index_col = 0)

# %% [raw]
# movie_detail = movie_detail[movie_detail["showTm"].notna()]

# %% [raw]
# movie_detail["showTm"] = movie_detail["showTm"].astype(int)
# #movie_info_df["movieCd"] = movie_info_df["showTm"].astype(int)

# %%
result = pd.merge(movie_info,movie_detail_df,on=['movieCd','movieNm'],how='inner')

# %%
result = result.drop_duplicates("movieCd").reset_index(drop=True)

# %%
result[result['movieCd'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [movieCd, movieNm, director, prdtYear, openDt, typeNm, repNationNm, repGenreNm, showTm, watchGradeNm, actor_1, actor_2, actor_3, companyNm]
# Index: []

# %%
result.to_csv("일단_result.csv",encoding="utf-8")  #info랑 detail 합

# %%
result
# Out:
#        movieCd                 movieNm    director  prdtYear      openDt  \
# 0     20162869                   택시운전사          장훈    2017.0  20170802.0
# 1     20150976               신과함께-죄와 벌         김용화    2017.0  20171220.0
# 2     20151228                      공조         김성훈    2016.0  20170118.0
# 3     20167303             스파이더맨: 홈 커밍        존 왓츠    2017.0  20170705.0
# 4     20172742                    범죄도시         강윤성    2017.0  20171003.0
# ...        ...                     ...         ...       ...         ...
# 6207  20100775                     소라닌     미키 타카히로    2010.0  20100826.0
# 6208  20100011              춤추는 꿈틀이 밴드  토마스 보르히 닐슨    2008.0  20100204.0
# 6209  20100277                내 남자의 순이         김호준    2010.0  20100527.0
# 6210  20100201  샤인 어 라이트(1st 지드래곤 콘서트)        정치영     2010.0  20100415.0
# 6211  20090639                  셉템버 이슈    R.J. 커들러    2009.0  20100128.0
#
#      typeNm repNationNm repGenreNm showTm watchGradeNm  actor_1   actor_2  \
# ...

# %%
result = pd.read_csv("일단_result.csv", index_col=0)

# %%
movie_df = pd.read_csv("일단movie.csv", index_col=0)

# %%
movie_df.rename(columns = {'영화명' : 'movieNm'}, inplace = True)
movie_df.rename(columns = {'개봉일' : 'openDt'}, inplace = True)
movie_df.rename(columns = {'매출액' : 'total_money'}, inplace = True)
movie_df.rename(columns = {'관객수' : 'audience'}, inplace = True)
movie_df.rename(columns = {'스크린수' : 'screen_num'}, inplace = True)
movie_df.rename(columns = {'상영횟수' : 'show_num'}, inplace = True)

# %%
result
# Out:
#        movieCd                 movieNm    director  prdtYear      openDt  \
# 0     20162869                   택시운전사          장훈    2017.0  20170802.0
# 1     20150976               신과함께-죄와 벌         김용화    2017.0  20171220.0
# 2     20151228                      공조         김성훈    2016.0  20170118.0
# 3     20167303             스파이더맨: 홈 커밍        존 왓츠    2017.0  20170705.0
# 4     20172742                    범죄도시         강윤성    2017.0  20171003.0
# ...        ...                     ...         ...       ...         ...
# 6207  20100775                     소라닌     미키 타카히로    2010.0  20100826.0
# 6208  20100011              춤추는 꿈틀이 밴드  토마스 보르히 닐슨    2008.0  20100204.0
# 6209  20100277                내 남자의 순이         김호준    2010.0  20100527.0
# 6210  20100201  샤인 어 라이트(1st 지드래곤 콘서트)        정치영     2010.0  20100415.0
# 6211  20090639                  셉템버 이슈    R.J. 커들러    2009.0  20100128.0
#
#      typeNm repNationNm repGenreNm  showTm watchGradeNm  actor_1   actor_2  \
# ...

# %%
result["prdtYear"] = result["prdtYear"].astype(int,errors='ignore')
result["openDt"] = result["openDt"].astype(int,errors='ignore')
result["openDt"] = result["openDt"].astype(object)

# %%
result.dtypes
# Out:
# movieCd          object
# movieNm          object
# director         object
# prdtYear        float64
# openDt           object
# typeNm           object
# repNationNm      object
# repGenreNm       object
# showTm          float64
# watchGradeNm     object
# actor_1          object
# actor_2          object
# actor_3          object
# companyNm        object
# dtype: object

# %%
movie_df.dtypes
# Out:
# movieNm        object
# openDt         object
# total_money    object
# audience        int64
# screen_num     object
# show_num       object
# 배급사            object
# dtype: object

# %%
movie_df["openDt"] = movie_df["openDt"].str.replace("-","")

# %%
result2 = pd.merge(movie_df,result,on=['movieNm'],how='inner')
result2 = result2.rename(columns={"openDt_x":"openDt"})
result2.drop(['openDt_y'],axis=1,inplace=True)

# %%
result2
# Out:
#                      movieNm    openDt  total_money  audience screen_num  \
# 0                      택시운전사  20170802  95853645649  12186327       1906
# 1                  신과함께-죄와 벌  20171220  68350496432   8539495       1912
# 2                         공조  20170118  63783051326   7817618       1392
# 3                스파이더맨: 홈 커밍  20170705  59125813820   7258678       1965
# 4                       범죄도시  20171003  56318014149   6879841       1315
# ...                      ...       ...          ...       ...        ...
# 4640                     소라닌  20100826    81223000      10913       13.0
# 4641              춤추는 꿈틀이 밴드  20100204    72851000      10885       47.0
# 4642                내 남자의 순이  20100527    73108500      10449       99.0
# 4643  샤인 어 라이트(1st 지드래곤 콘서트)  20100415    91164000      10349       14.0
# 4644                  셉템버 이슈  20100128    78736700      10202       11.0
#
#      show_num                       배급사   movieCd    director  prdtYear  \
# ...

# %%
result2[result2['movieCd'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [movieNm, openDt, total_money, audience, screen_num, show_num, 배급사, movieCd, director, prdtYear, typeNm, repNationNm, repGenreNm, showTm, watchGradeNm, actor_1, actor_2, actor_3, companyNm]
# Index: []

# %%
result2 = result2.drop_duplicates("movieCd").reset_index(drop=True)

# %%
result2.to_csv("일단_result2.csv",encoding="utf-8")

# %%
result = pd.read_csv("일단_result2.csv", index_col=0)

# %%
result.dtypes
# Out:
# movieNm          object
# openDt          float64
# total_money      object
# audience          int64
# screen_num       object
# show_num         object
# 배급사              object
# movieCd          object
# director         object
# prdtYear        float64
# typeNm           object
# repNationNm      object
# repGenreNm       object
# showTm          float64
# watchGradeNm     object
# actor_1          object
# actor_2          object
# actor_3          object
# companyNm        object
# dtype: object
