# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import re
import warnings
warnings.filterwarnings('ignore')

# %%
data_set = pd.read_excel("일단_data_set.xlsx")

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3884 entries, 0 to 3883
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movieNm          3884 non-null   object
#  1   openDt           3827 non-null   datetime64[ns]
#  2   total_money      3884 non-null   int64
#  3   audience         3884 non-null   int64
#  4   screen_num       3884 non-null   int64
#  5   show_num         3884 non-null   int64
#  6   배급사              3638 non-null   object
#  7   movieCd          3884 non-null   object
#  8   director         3884 non-null   object
#  9   prdtYear         3884 non-null   int64
#  10  typeNm           3884 non-null   object
#  11  repNationNm      3884 non-null   object
#  12  repGenreNm       3884 non-null   object
#  13  showTm           3876 non-null   float64
#  14  watchGradeNm     3857 non-null   object
#  15  actor_1          3643 non-null   object
# ...

# %%
data_set.describe()
# Out:
#         total_money      audience   screen_num       show_num     prdtYear  \
# count  3.884000e+03  3.884000e+03  3884.000000    3884.000000  3884.000000
# mean   3.327689e+09  4.213386e+05   237.686148   11714.088311  2010.333419
# std    9.918456e+09  1.222452e+06   321.240595   25549.180360    11.172324
# min    0.000000e+00  0.000000e+00     1.000000       1.000000  1920.000000
# 25%    4.642750e+06  9.100000e+02     4.000000      32.000000  2010.000000
# 50%    2.040172e+08  2.677300e+04   124.000000    1879.000000  2013.000000
# 75%    1.589244e+09  2.150852e+05   334.000000    9996.750000  2016.000000
# max    1.396518e+11  1.626562e+07  2835.000000  292584.000000  2021.000000
#
#             showTm   star_score  star_user_count  netizen_score  netizen_count
# count  3876.000000  3884.000000      3884.000000    3884.000000    3884.000000
# mean    105.190918     4.654428       435.177909       7.476262    2425.007981
# ...

# %%
data_set.rename(columns = {'배급사' : 'distributor'}, inplace = True)

# %%
data_set.columns
# Out:
# Index(['movieNm', 'openDt', 'total_money', 'audience', 'screen_num',
#        'show_num', 'distributor', 'movieCd', 'director', 'prdtYear', 'typeNm',
#        'repNationNm', 'repGenreNm', 'showTm', 'watchGradeNm', 'actor_1',
#        'actor_2', 'actor_3', 'companyNm', 'star_score', 'star_user_count',
#        'netizen_score', 'netizen_count'],
#       dtype='object')

# %%
plt.figure(figsize=[10,10])
sns.regplot(x=data_set['screen_num'], y=data_set['audience'],fit_reg=True, color = 'pink')
# Out:
# <AxesSubplot:xlabel='screen_num', ylabel='audience'>

# %%
plt.figure(figsize=[10,10])
sns.scatterplot(data=data_set, x='showTm', y = 'audience',marker='o',color='orange',alpha=0.5)
# Out:
# <AxesSubplot:xlabel='showTm', ylabel='audience'>

# %%
gen_data = data_set.groupby(['repGenreNm'], as_index=False).count()

# %%
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
plt.figure(figsize=[10,10])
plt.bar(gen_data['repGenreNm'], gen_data['audience'], color='purple')
plt.xticks(rotation=45)
plt.xlabel('장르', fontsize=10)
plt.ylabel('관객수', fontsize=10)
plt.show()

# %%
data_set.columns
# Out:
# Index(['movieNm', 'openDt', 'total_money', 'audience', 'screen_num',
#        'show_num', '배급사', 'movieCd', 'director', 'prdtYear', 'typeNm',
#        'repNationNm', 'repGenreNm', 'showTm', 'watchGradeNm', 'actor_1',
#        'actor_2', 'actor_3', 'companyNm', 'star_score', 'star_user_count',
#        'netizen_score', 'netizen_count'],
#       dtype='object')
